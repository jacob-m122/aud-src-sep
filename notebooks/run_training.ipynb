# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python src/train_model.py

# %%
# !ls -R
# Out:
# .:
# drive  sample_data
#
# ./drive:
# MyDrive
#
# ./drive/MyDrive:
#  01:31:25.wav
#  02:09:26.zip
# '03:20:25 - Aiden, Sam, Ian, Jacob.zip'
# '05:17:25-family in La Jolla'
#  11-2-25-edited
#  11:3:25-aiden.zip
#  1cleaned_Competitive_Analysis_Presentable.xlsx
# '2013 writing.pdf'
# '2014 writing.pdf'
# '2022 Media Release Template (1).pdf'
# '2025-05-03 17-34-32 (1).mp4'
# '2025-05-03 17-34-32.mp4'
# '2025-05-03 17-42-20.mp4'
#  299
# '"299" Score'
# '3-14-24, 1:54 PM Microsoft Lens.jpeg'
# '3-14-24, 1:55 PM Microsoft Lens.jpeg'
#  342-hw8-jacobm.pdf
# '5.1 Response.gdoc'
# '6.1 reading response.gdoc'
# '6 8 demo jam'
# '80s ethereal mov.mp4'
# '80s ethereal rave demo.wav'
# '84 drive'
# 'A3 - CS1B.gdoc'
# 'A-Ab bossa.m4a'
# 'Ableton demos'
# 'Ableton project exports'
#  absolutely_immaculate_fucking_guitar_loop_1.wav
# 'ADHD SELF-REPORT QUESTIONNAIRE - Jacob Mitani.pdf'
# 'Aiden 04-05-25.zip'
#  aiden-2-26.zip
# 'AIDEN AND I 06:05.zip'
# 'aiden email.gdoc'
# 'AIDEN-NOV 2024'
# ...
